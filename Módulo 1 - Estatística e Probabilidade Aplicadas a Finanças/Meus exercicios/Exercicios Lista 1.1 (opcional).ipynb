# %% [markdown]
# # Made by _[Lorenzo Cavalcante](https://github.com/LorenzoC5)_ & _[Gabriel Navarro](https://github.com/GB-Navarro)_

# %% [markdown]
# # 📊 **1 - Estatística e Probabilidade Aplicadas a Finanças**

# %% [markdown]
# ### **Exercícios** *(opcionais, mas altamente recomendados)*

# %% [markdown]
# ##### *1) Identificando $\Omega$, $\mathcal{F}$ e $P$*

# %% [markdown]
# Você observará amanhã se o preço de uma ação **subiu**, **caiu** ou **ficou igual** ao preço de hoje.
# 1. Proponha um $\Omega$ adequado.
# 2. Dê um exemplo de $\mathcal{F}$ **válida** (liste alguns subconjuntos de $\Omega$) e explique por que é uma sigma-álgebra.
# 3. Defina um $P$ simples (probabilidades plausíveis que somem 1).

# %% [markdown]
# 1. {subiu, caiu, ficou igual}
# 2. $\mathcal{F}$ = {$\emptyset$, {subiu}, {caiu}, {ficou igual}, {subiu, caiu}, {subiu, ficou igual}, {caiu, ficou igual}, {subiu, caiu, ficou igual}}
# Esta $\mathcal{F}$ é válida porque satisfaz as três regras:
# - Ela contém $\emptyset$ e $\Omega$.
# - O complemento de {subiu}, por exemplo, é {caiu, ficou igual}, e ambos estão na lista (fechada para complementos).
# - A união de {subiu} e {caiu}, por exemplo, é {subiu, caiu}, que também está na lista (fechada para uniões).
# 3.
# - $P(\{\text{subiu}\}) = 0.5$
# - $P(\{\text{caiu}\}) = 0.4$
# - $P(\{\text{ficou igual}\}) = 0.1$
#
# $0.5 + 0.4 + 0.1 = 1.0$. --> Medida de probabilidade válida.

# %% [markdown]
# ##### *2) "Dado" e eventos*

# %% [markdown]
# Considere um dado justo: $\Omega=\{1,2,3,4,5,6\}$.
# 1. Defina $A=\{2,4,6\}$ (pares) e $B=\{1,3,5\}$ (ímpares). Calcule $P(A)$, $P(B)$, $P(A\cup B)$, $P(A\cap B)$.
# 2. Se $C=\{1,2,3\}$, calcule $P(C^c)$ e verifique $P(C)+P(C^c)=1$.

# %% [markdown]
# 1.
# - $P(A)$ = 3/6 = 1/2
# - $P(B)$ = 3/6 = 1/2
# - $P(A\cup B)$ = 1
# - $P(A\cap B)$. = 0
#
# 2.
# - $P(C)$ = 3/6 = 1/2
# - Se $C = \{1, 2, 3\}$, então $C^c = \{4, 5, 6\}$
# - $P(C^c)$ = 3/6= 1/2
# - $P(C)$ + $P(C^c)$ = 1/2 + 1/2 = 1

# %% [markdown]
# ##### *3) É sigma-álgebra?*

# %% [markdown]
# Em $\Omega=\{a,b,c\}$, avalie se cada coleção é uma sigma-álgebra. Justifique.
# 1. $\mathcal{G}_1=\{\varnothing,\Omega\}$.
# 2. $\mathcal{G}_2=\{\varnothing,\{a\},\{b,c\},\Omega\}$.
# 3. $\mathcal{G}_3=\{\varnothing,\{a,b\},\Omega\}$.

# %% [markdown]
# 1. $\mathcal{G}_1=\{\varnothing,\Omega\}$. é sigma-álgebra, pois contém $\Omega$ e $\emptyset$ e eles são complementos um do outro, além de que $\emptyset \cup \Omega = \Omega$.
#
# 2. $\mathcal{G}_2=\{\varnothing,\{a\},\{b,c\},\Omega\}$. é sigma-álgebra, pois contém $\Omega$ e $\emptyset$, todos os complementos e uniões possíveis:
# - $Complemento(\emptyset) = \Omega$
# - $Complemento(\Omega) = \emptyset$
# - $Complemento(\{a\}) = \{b, c\}$
# - $Complemento(\{b, c\}) = \{a\}$.
# - $\emptyset \cup \{a\} = \{a\}$
# - $\{a\} \cup \{b, c\} = \{a, b, c\} = \Omega$
#
# 3. $\mathcal{G}_3=\{\varnothing,\{a,b\},\Omega\}$ não é sigma-álgebra, pois não contém o conjunto {c}.

# %% [markdown]
# ##### 4) *Frequências $\to$ Probabilidades*

# %% [markdown]
# Em 10 dias, o fechamento de um ativo resultou em: $\{\text{subiu}, \text{subiu}, \text{caiu}, \text{igual}, \text{subiu}, \text{caiu}, \text{caiu}, \text{subiu}, \text{igual}, \text{subiu}\}$.
# 1. Proponha $\Omega$ e uma $\mathcal{F}$ mínima natural.
# 2. Defina $P$ pelas **frequências relativas** e calcule $P(\text{subiu})$, $P(\text{caiu})$, $P(\text{igual})$.
# 3. Verifique $P(\Omega)=1$ e a aditividade para eventos disjuntos simples.

# %% [markdown]
# 1.
# - $\Omega = \{\text{subiu, caiu, igual}\}$;
# - $\mathcal{F} = \{\emptyset, \{\text{subiu}\}, \{\text{caiu}\}, \{\text{igual}\}, \{\text{subiu, caiu}\}, \{\text{subiu, igual}\}, \{\text{caiu, igual}\}, \Omega\}$
#
# 2.
# - Quantidade de "subiu": 5
# - Quantidade de "caiu": 3
# - Quantidade de "igual": 2
# - $P(\text{subiu}) = 5 / 10 = 0.5$
# - $P(\text{caiu}) = 3 / 10 = 0.3$
# - $P(\text{igual}) = 2 / 10 = 0.2$
#
# 3. $P(\Omega) = 0.5 + 0.3 + 0.2 = 1$
# - Aditividade:
# - Dois eventos disjuntos (que não podem acontecer ao mesmo tempo), por exemplo:
# - A = {subiu}
# - B = {caiu}
# - O evento união é $A \cup B$ = {subiu, caiu} (o evento "o preço mudou")
# - A regra da aditividade diz: $P(A \cup B) = P(A) + P(B)$.
# - $P(A) + P(B) = 0.5 + 0.3 = 0.8$.
# - $P(A \cup B)$ diretamente pelas frequências: A quantidade de "subiu ou caiu" foi $5 + 3 = 8$. A probabilidade é $8 / 10 = 0.8$.

# %% [markdown]
# ##### 5) *Refinando $\mathcal{F}$*

# %% [markdown]
# No dado justo, compare:
# - $\mathcal{F}_\text{mín}=\{\varnothing,\Omega\}$
# - $\mathcal{F}_\text{par/ímpar}=\{\varnothing,\{2,4,6\},\{1,3,5\},\Omega\}$
# - $\mathcal{F}_\text{toda}=2^\Omega$
#
# Dê exemplos de perguntas/eventos que **não** são mensuráveis em $\mathcal{F}_\text{mín}$, mas passam a ser em $\mathcal{F}_\text{par/ímpar}$ e, depois, em $2^\Omega$. Explique como aumentar $\mathcal{F}$ amplia o escopo de perguntas respondíveis pelo modelo.

# %% [markdown]
# 1. $\mathcal{F}_\text{mín}$ responde a probabilidade de algo acontecer ou não, mas não responde, por exemplo, a probabilidade de cair um número par ou ímpar, que é respondido em  $\mathcal{F}_\text{par/ímpar}$. Já $\mathcal{F}_\text{toda}$ consegue responder a probabilidade de cair um número específico. Aumentar a $\mathcal{F}$ significa aumentar a quantidade de informação que o modelo de probabilidade possui, assim é possível responder mais perguntas.

# %% [markdown]
# ### **Outros Exercícios**

# %% [markdown]
# ##### *6) Independência de eventos*

# %% [markdown]
# Considere um dado justo (faces $1$–$6$) e dois lançamentos independentes.
#
# 1. No **primeiro** lançamento, defina $A=\{\text{par}\}$ e $B=\{\text{resultado}>4\}$. Calcule $P(A)$, $P(B)$ e $P(A\cap B)$. Verifique se $A$ e $B$ são independentes checando $P(A\cap B)=P(A)P(B)$.
# 2. Agora, em **dois** lançamentos, defina $C=\{\text{a soma é }7\}$ e $D=\{\text{o primeiro resultado é par}\}$. Calcule $P(C)$, $P(D)$ e $P(C\cap D)$ e teste a independência de $C$ e $D$.
# 3. Explique, em 2–3 linhas, por que “lançamentos independentes” **não** implica que quaisquer eventos construídos sobre eles sejam independentes (use o par $C$, $D$ como exemplo).

# %% [markdown]
# 1.
# - $P(A)$ = 3/6 = 1/2
# - $P(B)$ = 2/6 = 1/3
# - $P(A\cap B)$ = 1/6
# - $P(A\cap B)$= 1/2 * 1/3 = 1/6. Portanto, A e B são independentes.
#
# 2.
# - $C = \{(1,6), (2,5), (3,4), (4,3), (5,2), (6,1)\}$
# - $D = \{(2,1), (2,2), ... (2,6), (4,1), ... (4,6), (6,1), ... (6,6)\}$
# - $P(C) = 6/36 = 1/6$
# - $P(D) = 18/36 = 1/2$
# - $P(C \cap D) = 3/36 = 1/12$
# - Teste de independência: $P(C \cap D) = 1/6 * 1/2 = 1/12$. Portanto, C e D são independentes.
#
# 3. Apesar dos lançamentos serem independentes, os eventos C e D poderiam ser dependentes, pois o evento D ('primeiro é par') restringe o universo de resultados possíveis. Alguém poderia achar que isso mudaria a probabilidade de C ('soma 7'). Contudo, ao calcular $P(C|D)$ (a probabilidade de C dado que D ocorreu), vemos que ela é $3/18 = 1/6$, que é a mesma coisa que $P(C)$. Portanto, nesse caso específico, os eventos acabaram sendo independentes, embora em geral isso não seja verdade para qualquer par de eventos.

# %% [markdown]
# ##### *7) Teorema de Bayes (diagnóstico)*

# %% [markdown]
# Um teste para uma condição rara tem **sensibilidade** $0{,}95$ e **especificidade** $0{,}98$. A prevalência na população é $0{,}5\%$.
#
# 1. Calcule $P(\text{positivo})$ pela lei total:
#    $$P(+) = P(+\mid \text{doente})P(\text{doente}) + P(+\mid \text{saudável})P(\text{saudável}).$$
# 2. Use Bayes para encontrar a **probabilidade pós-teste**:
#    $$P(\text{doente}\mid +) = \frac{P(+\mid \text{doente})P(\text{doente})}{P(+)}.$$
# 3. Se um **segundo teste independente** com sensibilidade $0{,}90$ e especificidade $0{,}99$ também der **positivo**, atualize a probabilidade de estar doente (assuma independência condicional dados os estados).

# %% [markdown]
# 1.
# - $P(+) = (0.95) \cdot (0.005) + (0.02) \cdot (0.995)$ = $P(+) = 0.00475 + 0.0199$ = $P(+) = 0.02465$ (ou 2.465%) --> Probabilidade total de qualquer pessoa na população testar positivo.
#
# 2.
# - $P(\text{doente}\mid +) = \frac{0.00475}{0.02465}$ $\approx 0.1927$ (ou 19.27%). Portanto, mesmo com um teste positivo, a chance da pessoa estar doente é de apenas 19.27%. Isso acontece porque a doença é muito rara (0.5%), então o número de falsos positivos (2% sobre 99.5% da população) é muito maior que o número de verdadeiros positivos (95% sobre 0.5% da população).
#
# 3.
# - $P'(\text{doente}) = 0.1927$; $P'(\text{saudável}) = 1 - 0.1927 = 0.8073$
# - $P(\text{+2}\mid \text{doente}) = 0.90$; $P(\text{+2}\mid \text{saudável}) = 1 - 0.99 = 0.01$
# - $P'(+2) = P(\text{+2}\mid \text{doente}) \cdot P'(\text{doente}) + P(\text{+2}\mid \text{saudável}) \cdot P'(\text{saudável})$
# - $P'(+2) = (0.90) \cdot (0.1927) + (0.01) \cdot (0.8073)$
# - $P'(+2) = 0.17343 + 0.008073$ $ \approx 0.1815$
#
# - $P'(\text{doente}\mid +2) = \frac{P(\text{+2}\mid \text{doente}) \cdot P'(\text{doente})}{P'(+2)}$
# - $P'(\text{doente}\mid +2) = \frac{0.17343}{0.1815}$
# - $P'(\text{doente}\mid +2) \approx 0.9555$ (ou 95.55%). Após um segundo resultado positivo, a crença de que a pessoa está doente sobe de 19.27% para 95.55%.

# %% [markdown]
# ##### *8) Covariância e correlação*

# %% [markdown]
# Seja $(X,Y)$ com a seguinte distribuição conjunta (todos os demais pares têm probabilidade $0$):
#
# <div align="center">
#
# | $x$ \ $y$ |   $0$   |   $1$   |
# |:---------:|:-------:|:-------:|
# |    $1$    | $0{,}20$| $0{,}30$|
# |    $2$    | $0{,}10$| $0{,}40$|
#
# </div>
#
# 1. Calcule as marginais $P_X$ e $P_Y$ e, em seguida, $E[X]$, $E[Y]$.
# 2. Encontre $E[XY]$ e a **covariância** $\operatorname{Cov}(X,Y)=E[XY]-E[X]E[Y]$.
# 3. Calcule a **correlação** $\rho_{X,Y}=\dfrac{\operatorname{Cov}(X,Y)}{\sqrt{\operatorname{Var}(X)\operatorname{Var}(Y)}}$.
# 4. Interprete o **sinal** e a **magnitude** de $\rho_{X,Y}$ em 1–2 linhas.

# %% [markdown]
# 1. Marginais:
# - $P_X$​(1) = 0,20 + 0,30 = 0,50
# - $P_X$(2) = 0,10 + 0,40 = 0,50
# - $P_Y$(0) = 0,20 + 0,10 = 0,30
# - $P_Y$(1) = 0,30 + 0,40 = 0,70
#
# Esperanças:
# - $E[X]$ = (1 * 0.5) + (2 * 0,5) = 0,5 + 1,0 = 1,5
# - $E[Y]$ = (0 * 0,3) + (1 * 0,7) = 0 + 0,7 = 0,7
#
# 2. $E[XY]$ = ∑xyp(x,y):
# - 1 * 0 * 0,20 = 0
# - 1 * 1 * 0,30 = 0,30
# - 2 * 0 * 0,10 = 0
# - 2 * 1 * 0,40 = 0,80
# $E[XY]$ = 0 + 0,30 + 0 + 0,80 = 1,10
#
# Covariância:
# - $\operatorname{Cov}(X,Y)=E[XY]-E[X]E[Y]$ = 1,10 - (1,5 * 0,7) = 1,10 - 1,05 = 0,05
#
# 3. Correlação $\rho_{X,Y}=\dfrac{\operatorname{Cov}(X,Y)}{\sqrt{\operatorname{Var}(X)\operatorname{Var}(Y)}}$
# - $E[X²]$ = (1² * 0,5) + (2² * 0,5) = 0,5 + 2 = 2,5; Var(X) = $E[X²]$ - $E[X]²$ = 2,5 - 1,5² = 0,25
# - $E[Y²]$ = (0² * 0,3) + (1² * 0,7) = 0,7; Var(Y) = $E[Y²]$ - $E[Y]²$ = 0,7 - 0,7² = 0,21
#
# $\rho_{X,Y}=\dfrac{0,05}{\sqrt{0,25 * 0,21}} \approx 0.2182$
#
#
# 4. O sinal é positivo, o que indica que, em média, valores maiores de X tendem a associar-se a valores maiores de Y. A magnitude (~0.22) é baixa, ou seja, existe uma relação linear fraca entre X e Y.

# %% [markdown]
# ##### *9) Variáveis aleatórias: PMF, CDF e transformações*

# %% [markdown]
# Considere um dado justo. Defina $X=Z$ (o valor observado) e $Y=\mathbf{1}\{\text{par}\}$.
#
# 1. Escreva a **PMF** de $X$ e $Y$ e as **CDFs** $F_X$, $F_Y$.
# 2. Calcule $E[X]$, $\operatorname{Var}(X)$, $E[Y]$ e $\operatorname{Var}(Y)$.
# 3. Para $W=2X-3$, encontre $E[W]$ e $\operatorname{Var}(W)$ usando **linearidade** e a regra para variâncias sob transformação linear.
# 4. Seja $S=X+Y$. Liste a **PMF** de $S$ (valores possíveis e probabilidades) e calcule $E[S]$.

# %% [markdown]
# 1. PMF de X:
# - $P_X(k)$ = $P(X = k)$ = 1/6, k = 1, 2, 3, 4, 5, 6
# - CDF de X:
# - $F_X(x)$ = $P(X ≤ x)$ =
# - 0, x < 1;
# - 1/6, 1 ≤ x < 2;
# - 2/6, 2 ≤ x < 3;
# - 3/6, 3 ≤ x < 4;
# - 4/6, 4 ≤ x < 5;
# - 5/6, 5 ≤ x < 6;
# - 1, x ≥ 6.
#
# - PMF de Y:
# - $P_Y$(1) = 1/2; $P_Y(0)$ = 1/2
# - CDF de Y:
# $F_X$(y) = $P(Y ≤ y)$ =
# - 0, y < 0;
# - 1/2, 0 ≤ y < 1;
# - 1, y ≥ 1.
#
# 2.
# - $E[X]$ = (1 + 2 + 3 + 4 + 5 + 6)/6 = 3,5
# - $E[X²]$ = (1² + 2² + 3² + 4² + 5² + 6²)/6 = 91/6
# - Var(X) = 91/6 - 3,5² = 35/12 $\approx$ 2,9167
# - $E[Y]$ = $P(Y = 1)$ = 1/2
# - Var(Y) = p(1 - p) = 1/2 * 1/2 = 1/4
#
# 3.
# - $E[W]$ = 2$E[X]$ - 3 = 2 * 3,5 - 3 = 4
# - Var(W) = 2² * Var(X) = 4 * 35/12 = 35/3 $\approx$ 11,6667
#
# 4.
# - S = 1 quando X = 1 (prob. 1/6)
# - S = 3 quando X = 3 ou X = 2 (prob. 1/6 + 1/6 = 2/6 = 1/3)
# - S = 5 quando X = 5 ou X = 4 (prob. 1/3)
# - S = 7 quando X = 6 (prob. 1/6)
# - PMF de S:
# - $P(S = 1)$ = 1/6;
# - $P(S = 3)$ = 1/3;
# - $P(S = 5)$ = 1/3;
# - $P(S = 7)$ = 1/6.
# - 1/6 + 1/3 + 1/3 + 1/6 = 1
# - $E[S]$ = $E[X + Y]$ = $E[X]$ + $E[Y]$ = 3,5 + 0,5 = 4
